# %%
#Working Verison

space = list("---------")
move = 0 
gameWon = False
turn = ["O","X"]
go = 0



#winningSets = ['...CCC...', '......CCC', '..C..C..C', '.C..C..C.', '..C.C.C..', 'CCC......', 'C..C..C..', 'C...C...C']
#victory_conditions = (string[0] == "C" and string[1] == "C" and string[2] == "C") or \
 #                     (string[3] == "C" and string[4] == "C" and string[5] == "C") or \
  #                    (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
   #                   (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
    #                  (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
     #                 (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
      #                (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
       #               (string[2] == "C" and string[4] == "C" and string[6] == "C")


def render():
    for i in range(3):
        print(space[3*i],space[3*i+1],space[3*i+2])

        
def player(turn, go):
    while gameWon == False:
        move = input("move? 1-9  ")
        
        try:
            move = int(move) - 1
        except:
            print("must be interger 1-9")
            continue
        
        if space[move] == "-":
            space[move] = turn[go]
        else:
            print("cannot move to occupied space")
            continue
        
        render()
        
        if go == 0:
            string = ''.join(space)
            string = string.replace(turn[1],"-")
            string = string.replace(turn[0],"C") # there must be a more efficent way of doing the win check!
            #print(string)
            if (string[0] == "C" and string[1] == "C" and string[2] == "C") or \
                      (string[3] == "C" and string[4] == "C" and string[5] == "C") or \
                      (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
                      (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
                      (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
                      (string[2] == "C" and string[4] == "C" and string[6] == "C"):
                print(turn[go], " has won!")
                break
                
            go = 1
        else:
            string = ''.join(space)
            string = string.replace(turn[0],"-")
            string = string.replace(turn[1],"C")
            #print(string)
            if (string[0] == "C" and string[1] == "C" and string[2] == "C") or \
                      (string[3] == "C" and string[4] == "C" and string[5] == "C") or \
                      (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
                      (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
                      (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
                      (string[2] == "C" and string[4] == "C" and string[6] == "C"):
                print(turn[go], " has won!")
                break
           
            go = 0
            
    

        
       
        
        
render()
player(turn, go)
# Out:
# - - -
# - - -
# - - -
# move? 1-9  1
# O - -
# - - -
# - - -
# move? 1-9  5
# O - -
# - X -
# - - -
# move? 1-9  9
# O - -
# - X -
# - - O
# move? 1-9  7
# O - -
# - X -
# X - O
# move? 1-9  3
# O - O
# - X -
# X - O
# move? 1-9  6
# O - O
# - X X
# X - O
# move? 1-9  2
# O O O
# - X X
# X - O
# O  has won!

# %%
import re
space = list("---------")
move = 0 
gameWon = False
turn = ["O","X"]
go = 0

winningSets = ('...CCC...', '......CCC', '..C..C..C', '.C..C..C.', '..C.C.C..', 'CCC......', 'C..C..C..', 'C...C...C')


def render():
    for i in range(3):
        print(space[3*i],space[3*i+1],space[3*i+2])

        
def player(turn, go):
    while gameWon == False:
        move = input("move? 1-9  ")
        
        try:
            move = int(move) - 1
        except:
            print("must be interger 1-9")
            continue
        
        if space[move] == "-":
            space[move] = turn[go]
        else:
            print("cannot move to occupied space")
            continue
        
        render()
        
        if go == 0:
            string = ''.join(space)
            string = string.replace(turn[1],"-")
            string = string.replace(turn[0],"C") # there must be a more efficent way of doing the win check!
            print(string)
            if any(re.search(winningSets[1], string) for winningSet in winningSets):
                print(turn[go], " has won!")
                
            go = 1
        else:
            string = ''.join(space)
            string = string.replace(turn[0],"-")
            string = string.replace(turn[1],"C")
            print(string)

            go = 0
        
       
        
        
render()
player(turn, go)
# Out:
# - - -
# - - -
# - - -
# move? 1-9  1
# O - -
# - - -
# - - -
# C--------
# move? 1-9  2
# O X -
# - - -
# - - -
# -C-------
# move? 1-9  3
# O X O
# - - -
# - - -
# C-C------
# move? 1-9  4
# O X O
# X - -
# - - -
# -C-C-----
# move? 1-9  5
# O X O
# X O -
# - - -
# C-C-C----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-aca5a97eaa38> in <module>
#      53
#      54 render()
# ---> 55 player(turn, go)
#      56
#      57
#
# <ipython-input-29-aca5a97eaa38> in player(turn, go)
#      16 def player(turn, go):
#      17     while gameWon == False:
# ---> 18         move = input("move? 1-9  ")
#      19
#      20         try:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# ...

# %%
space = list("---------")
move = 0 
gameWon = False
turn = ["O","X"]
go = 0



#winningSets = ['...CCC...', '......CCC', '..C..C..C', '.C..C..C.', '..C.C.C..', 'CCC......', 'C..C..C..', 'C...C...C']
#victory_conditions = (string[0] == "C" and string[1] == "C" and string[2] == "C") or \
 #                     (string[3] == "C" and string[4] == "C" and string[5] == "C") or \
  #                    (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
   #                   (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
    #                  (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
     #                 (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
      #                (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
       #               (string[2] == "C" and string[4] == "C" and string[6] == "C")


def render():
    for i in range(3):
        print(space[3*i],space[3*i+1],space[3*i+2])

        
def player(turn, go):
    while gameWon == False:
        move = input("move? 1-9  ")
        
        try:
            move = int(move) - 1
        except:
            print("must be interger 1-9")
            continue
        
        if space[move] == "-":
            space[move] = turn[go]
        else:
            print("cannot move to occupied space")
            continue
        
        render()
        
        if go == 0:
            string = ''.join(space)
            string = string.replace(turn[1],"-")
            string = string.replace(turn[0],"C") # there must be a more efficent way of doing the win check!
            print(string)
            if (string[0] == "C" and string[1] == "C" and string[2] == "C") or \
                      (string[3] == "C" and string[4] == "C" and string[5] == "C") or \
                      (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
                      (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
                      (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
                      (string[2] == "C" and string[4] == "C" and string[6] == "C"):
                print(turn[go], " has won!")
                break
                
            go = 1
        else:
            string = ''.join(space)
            string = string.replace(turn[0],"-")
            string = string.replace(turn[1],"C")
            print(string)
            if (string[0] == "C" and string[1] == "C" and string[2] == "C") or \
                      (string[3] == "C" and string[4] == "C" and string[5] == "C") or \
                      (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
                      (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
                      (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
                      (string[2] == "C" and string[4] == "C" and string[6] == "C"):
                print(turn[go], " has won!")
                break
           
            go = 0
            
    

        
       
        
        
render()
player(turn, go)
# Out:
# - - -
# - - -
# - - -
# move? 1-9  1
# O - -
# - - -
# - - -
# C--------
# move? 1-9  5
# O - -
# - X -
# - - -
# ----C----
# move? 1-9  2
# O O -
# - X -
# - - -
# CC-------
# move? 1-9  6
# O O -
# - X X
# - - -
# ----CC---
# move? 1-9  3
# O O O
# - X X
# - - -
# CCC------
# O  has won!

# %%
string[0] == "C" and string[1] == "C" and string [2] == "C",
                     string[3] == "C" and string[4] == "C" and string[5] == "C",
                     string[6] == "C" and string[7] == "C" and string[8] == "C",
                     string[0] == "C" and string[3] == "C" and string[6] == "C",
                     string[1] == "C" and string[4] == "C" and string[7] == "C",
                     string[2] == "C" and string[5] == "C" and string[8] == "C",
                     string[0] == "C" and string[4] == "C" and string[8] == "C",
                     string[2] == "C" and string[4] == "C" and string[6] == "C")
                    
                    
                    
(string[3] == "C" and string[4] == "C" and string[5] == "C") or \
                      (string[6] == "C" and string[7] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[3] == "C" and string[6] == "C") or \
                      (string[1] == "C" and string[4] == "C" and string[7] == "C") or \
                      (string[2] == "C" and string[5] == "C" and string[8] == "C") or \
                      (string[0] == "C" and string[4] == "C" and string[8] == "C") or \
                      (string[2] == "C" and string[4] == "C" and string[6] == "C")
# Out:
# [True, False, False, False, False, False, False, False]

# %%
winningSets = ["CCC------","---CCC---","------CCC",
               "C--C--C--","-C--C--C-","--C--C--C",
              "C---C---C","--C-C-C--"]

setList = ''.join(winningSets)

setList = setList.replace("-",".")

n = len(setList) // 8
substrings = set(setList[i:i + n] for i in range(0, len(setList), n))

print(substrings)
# Out:
# {'...CCC...', '......CCC', '..C..C..C', '.C..C..C.', '..C.C.C..', 'CCC......', 'C..C..C..', 'C...C...C'}
